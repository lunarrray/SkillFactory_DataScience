# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data_ps.csv')
melb_df = melb_data.copy()

# %% [markdown]
# #### Задание 2.1

# %%
price_square = melb_df['Price'] **2
price_square
# Out:
# 0        2.190400e+12
# 1        1.071225e+12
# 2        2.146225e+12
# 3        7.225000e+11
# 4        2.560000e+12
#              ...
# 13575    1.550025e+12
# 13576    1.062961e+12
# 13577    1.368900e+12
# 13578    6.250000e+12
# 13579    1.651225e+12
# Name: Price, Length: 13580, dtype: float64

# %% [markdown]
# #### Задание 2.3 (External resource) - Напишите функцию delete_columns(df, col=[]), которая удаляет столбцы из DataFrame и возвращает новую таблицу. Если одного из указанных столбцов не существует в таблице, то функция должна возвращать None.

# %%
def delete_columns(df, col = []):
    for column in col:
        if column not in df:
            return None
    result_df = df.drop(col, axis=1)
    return result_df

# %%
customer_df = pd.DataFrame({
            'number': [0, 1, 2, 3, 4],
            'cust_id': [128, 1201, 9832, 4392, 7472],
            'cust_age': [13, 21, 19, 21, 60],
            'cust_sale': [0, 0, 0.2, 0.15, 0.3],
            'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
            'cust_order': [1400, 14142, 900, 1240, 8430]
        })
new_df = delete_columns(customer_df, ['number', 'cust_year_birth', 'var'])
new_df

# %% [markdown]
# #### Задание 2.4 - Задан DataFrame countries_df, содержащий следующие столбцы: название страны, население (population) в миллионах человек и площадь страны (area) в квадратных километрах. Для каждой страны рассчитайте плотность населения (количество человек на квадратный километр). Затем по полученным данным рассчитайте среднее по плотностям населения в указанных странах. Ответ округлите до сотых. Плотность населения рассчитывается как количество человек, проживающих на территории отдельной страны, делённое на площадь этой страны. Обратите внимание, что население в таблице представлено в миллионах.

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
countries_df['PopulatianDensity'] = countries_df['population'] * 1e6 / countries_df['area']
#print(countries_df)
print(round(countries_df['PopulatianDensity'].mean(),2))
# Out:
# 84.93

# %% [markdown]
# #### Задание 3.3 - Создайте в таблице melb_df признак WeekdaySale (день недели). Найдите, сколько объектов недвижимости было продано в выходные (суббота и воскресенье), результат занесите в переменную weekend_count. В качестве ответа введите результат вывода переменной weekend_count.

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
weekend_count = melb_df[(melb_df['WeekdaySale'] == 5) | (melb_df['WeekdaySale'] == 6)].shape[0]
weekend_count
# Out:
# 12822

# %% [markdown]
# #### Задание 3.4 - В каком году отмечается наибольшее количество случаев наблюдения НЛО в США?

# %%
ufo_data = pd.read_csv('data/ufo.csv')
ufo_df = ufo_data.copy()
ufo_df['Time'] = pd.to_datetime(ufo_df['Time'])
ufo_df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-06-01 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-06-01 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
ufo_df['Time'].value_counts()
# Out:
# Time
# 1999-11-16 19:00:00    27
# 1999-11-16 18:05:00    20
# 1999-09-01 21:30:00    19
# 1999-11-16 19:05:00    19
# 1999-11-16 18:00:00    17
#                        ..
# 2000-12-29 00:00:00     1
# 2000-12-29 09:00:00     1
# 2000-12-29 16:10:00     1
# 2000-12-29 19:30:00     1
# 2000-12-27 22:10:00     1
# Name: count, Length: 16145, dtype: int64

# %% [markdown]
# #### Задание 3.5 - Найдите средний интервал времени (в днях) между двумя последовательными случаями наблюдения НЛО в штате Невада (NV).

# %%
ufo_df['Date'] = ufo_df['Time'].dt.date
nv_df = ufo_df[ufo_df['State'] == 'NV']
delta = nv_df['Date'].diff()
delta.dt.days.mean()
# Out:
# np.float64(68.92932862190813)

# %% [markdown]
# #### Задание 4.2 - Ранее, в задании 3.3, мы создали признак WeekdaySale в таблице melb_df — день недели продажи. Из полученных в задании результатов можно сделать вывод, что объекты недвижимости в Мельбурне продаются преимущественно по выходным (суббота и воскресенье). Напишите функцию get_weekend(weekday), которая принимает на вход элемент столбца WeekdaySale и возвращает 1, если день является выходным, и 0 — в противном случае, и создайте столбец Weekend в таблице melb_df с помощью неё. Примените эту функцию к столбцу и вычислите среднюю цену объекта недвижимости, проданного в выходные дни. Результат округлите до целых.

# %%
def get_weekend(weekday):
    if weekday in [5, 6]:
        return 1
    return 0

melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
melb_df
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
melb_df[melb_df['Weekend'] == 1]['Price'].mean()
# Out:
# np.float64(1081198.6406956792)

# %% [markdown]
# #### Задание 4.3 - Преобразуйте столбец SellerG с наименованиями риелторских компаний в таблице melb_df следующим образом: оставьте в столбце только 49 самых популярных компаний, а остальные обозначьте как 'other'. Найдите, во сколько раз минимальная цена объектов недвижимости, проданных компанией 'Nelson', больше минимальной цены объектов, проданных компаниями, обозначенными как 'other'. Ответ округлите до десятых.

# %%
popular_sellers = melb_df['SellerG'].value_counts().nlargest(49)
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_sellers else 'other')
melb_df['SellerG']
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object

# %%
nelson_min_price = melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min()
other_min_price = melb_df[melb_df['SellerG'] == 'other']['Price'].min()
print(round(nelson_min_price/other_min_price, 1))
# Out:
# 1.3

# %% [markdown]
# #### Задание 4.4
# ##### Представьте, что вы занимаетесь подготовкой данных о вакансиях с платформы hh.ru. В вашем распоряжении имеется таблица, в которой с помощью парсинга собраны резюме кандидатов. В этой таблице есть текстовый столбец «Опыт работы». Пример такого столбца представлен ниже в виде объекта Series. Структура текста в столбце фиксирована и не может измениться. Напишите функцию get_experience(arg), аргументом которой является строка столбца с опытом работы. Функция должна возвращать опыт работы в месяцах. Не забудьте привести результат к целому числу. Примечание. Обратите внимание, что опыт работы может выражаться только в годах или только в месяцах. Учтите это при построении своей функции.

# %%
def get_experience(arg: str):
    exp_list = arg.split(' ')
    month_count = 0
    if 'месяц' in exp_list[-1]:
        month_count += int(exp_list[-2])
        exp_list = exp_list[:-2]
    if 'год' in exp_list[-1] or 'лет' in exp_list[-1]:
        month_count += (int(exp_list[-2]) * 12)
    return month_count

# %%
str_exp1 = 'Опыт работы 8 лет 3 месяца'
str_exp2 = 'Опыт работы 3 года 5 месяцев'
str_exp3 = 'Опыт работы 3 месяцев'
str_exp4 = 'Опыт работы 6 лет'

print(get_experience(str_exp1))
print(get_experience(str_exp2))
print(get_experience(str_exp3))
print(get_experience(str_exp4))
# Out:
# 99
# 41
# 3
# 72

# %% [markdown]
# #### Задание 5.2
# ##### При преобразовании столбцов таблицы о недвижимости к типу category мы оставили без внимания столбец Suburb (пригород). Давайте исправим это.С помощью метода info() узнайте, сколько памяти занимает таблица melb_df.Преобразуйте признак Suburb следующим образом: оставьте в столбце только 119 наиболее популярных пригородов, остальные замените на 'other' Приведите данные в столбце Suburb к категориальному типу. В качестве ответа запишите разницу между объёмом занимаемой памяти до преобразования (который мы получили ранее в модуле) и после него в Мб. Ответ округлите до десятых.

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bathroom', 'Car', 'Bedroom']
max_unique_counts = 150
for col in melb_df.columns:
    if melb_df[col].nunique() < max_unique_counts and col not in cols_to_exclude:
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  category
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  category
#  7   SellerG        13580 non-null  category
#  8   Date           13580 non-null  datetime64[ns]
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  category
# ...

# %%
popular_suburb = melb_df['Suburb'].value_counts().nlargest(119)
melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: x if x in popular_sellers else 'other')
melb_df['Suburb'] = melb_df['Suburb'].astype('category')
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  category
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  category
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  category
#  7   SellerG        13580 non-null  category
#  8   Date           13580 non-null  datetime64[ns]
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  category
# ...

# %%
citibike_tripdata = pd.read_csv('data/citibike-tripdata.csv')
citibike_trip_df = citibike_tripdata.copy()
citibike_trip_df
# Out:
#                        starttime                  stoptime  start station id  \
# 0       2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1       2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2       2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3       2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4       2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
# ...                          ...                       ...               ...
# 299995  2018-09-05 19:08:27.8460  2018-09-05 19:15:51.4940             494.0
# 299996  2018-09-05 19:08:28.3700  2018-09-05 19:20:01.5080            3016.0
# 299997  2018-09-05 19:08:27.5090  2018-09-05 19:13:40.5060            3686.0
# 299998  2018-09-05 19:08:29.2300  2018-09-05 20:04:29.3220             254.0
# 299999  2018-09-05 19:08:29.7110  2018-09-05 19:12:14.7620            3496.0
#
# ...

# %% [markdown]
# #### Задание 6.1 - Сколько пропусков в столбце start station id?

# %%
citibike_trip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %% [markdown]
# #### Задание 6.3 - Найдите идентификатор самой популярной стартовой стоянки. Запишите идентификатор в виде целого числа.

# %%
citibike_trip_df['start station id'].value_counts()
# Out:
# start station id
# 281.0     1928
# 2006.0    1909
# 519.0     1873
# 514.0     1845
# 426.0     1835
#           ...
# 3432.0      15
# 3599.0      11
# 2005.0       9
# 3704.0       7
# 3583.0       6
# Name: count, Length: 759, dtype: int64

# %% [markdown]
# #### Задание 6.4 - Велосипед с каким идентификатором является самым популярным?

# %%
citibike_trip_df['bikeid'].value_counts()
# Out:
# bikeid
# 33887    107
# 34358    104
# 34159    103
# 34258    103
# 34314    102
#         ...
# 32682      1
# 18260      1
# 34554      1
# 34518      1
# 25794      1
# Name: count, Length: 10004, dtype: int64

# %% [markdown]
# #### Задание 6.5 - Какой тип клиентов (столбец usertype) является преобладающим — Subscriber или Customer? В качестве ответа запишите долю клиентов преобладающего типа среди общего количества клиентов. Ответ округлите до сотых.

# %%
citibike_trip_df['usertype'].value_counts(normalize=True)
# Out:
# usertype
# Subscriber    0.774007
# Customer      0.225993
# Name: proportion, dtype: float64

# %% [markdown]
# #### Задание 6.6 - Кто больше занимается велоспортом — мужчины или женщины? В ответ запишите число поездок для той группы, у которой их больше.

# %%
citibike_trip_df['gender'].value_counts()
# Out:
# gender
# 1    183582
# 2     74506
# 0     41912
# Name: count, dtype: int64

# %% [markdown]
# #### Задание 6.7

# %%
display(citibike_trip_df['end station id'].nunique())
display(citibike_trip_df['start station id'].nunique())
age = 2018 - citibike_trip_df['birth year']
display(age.min())
display(citibike_trip_df['start station name'].value_counts())
display(citibike_trip_df['end station name'].value_counts())
# Out:
# 765
# 759
# np.int64(16)
# start station name
# Grand Army Plaza & Central Park S    1928
# Central Park S & 6 Ave               1909
# Pershing Square North                1873
# 12 Ave & W 40 St                     1845
# West St & Chambers St                1835
#                                      ...
# NYCBS Depot - GOW                      15
# Franklin Ave & Empire Blvd             11
# Railroad Ave & Kay Ave                  9
# 47 Ave & Skillman Ave                   7
# Eastern Pkwy & Washington Ave           6
# Name: count, Length: 759, dtype: int64
# end station name
# West St & Chambers St          1963
# 12 Ave & W 40 St               1909
# Pershing Square North          1850
# Central Park S & 6 Ave         1828
# E 17 St & Broadway             1804
#                                ...
# Exchange Place                    3
# Union St                          1
# Montrose Ave & Bushwick Ave       1
# Warren St                         1
# ...

# %% [markdown]
# #### Задание 6.8 - В первую очередь удалим лишнюю информацию из данных. В наших данных присутствуют столбцы, которые дублируют информацию друг о друге: это столбцы с идентификатором и названием стартовой и конечной стоянки. Удалите признаки идентификаторов стоянок. Сколько столбцов осталось?

# %%
citibike_trip_df = citibike_trip_df.drop(['end station id', 'start station id'], axis=1)

# %%
display(citibike_trip_df.columns)
# Out:
# Index(['starttime', 'stoptime', 'start station name', 'start station latitude',
#        'start station longitude', 'end station name', 'end station latitude',
#        'end station longitude', 'bikeid', 'usertype', 'birth year', 'gender'],
#       dtype='object')

# %% [markdown]
# #### Задание 6.9 - Замените признак birth year на более понятный признак возраста клиента age. Годом отсчёта возраста выберите 2018 год. Столбец birth year удалите из таблицы. Сколько поездок совершено клиентами старше 60 лет?

# %%
citibike_trip_df['age'] = 2018 - citibike_trip_df['birth year']
citibike_trip_df = citibike_trip_df.drop(['birth year'], axis=1)
citibike_trip_df
# Out:
#                        starttime                  stoptime  \
# 0       2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1       2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2       2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3       2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4       2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
# ...                          ...                       ...
# 299995  2018-09-05 19:08:27.8460  2018-09-05 19:15:51.4940
# 299996  2018-09-05 19:08:28.3700  2018-09-05 19:20:01.5080
# 299997  2018-09-05 19:08:27.5090  2018-09-05 19:13:40.5060
# 299998  2018-09-05 19:08:29.2300  2018-09-05 20:04:29.3220
# 299999  2018-09-05 19:08:29.7110  2018-09-05 19:12:14.7620
#
#                      start station name  start station latitude  \
# 0          MacDougal St & Washington Sq               40.732264
# 1       Cadman Plaza West & Montague St               40.693830
# ...

# %%
display(citibike_trip_df[citibike_trip_df['age'] > 60].shape[0])
# Out:
# 11837

# %% [markdown]
# #### Задание 6.10 - Создайте признак длительности поездки trip duration. Для этого вычислите интервал времени между временем окончания поездки (stoptime) и её началом (starttime). Сколько целых минут длилась поездка под индексом 3 в таблице?

# %%
citibike_trip_df['starttime'] = pd.to_datetime(citibike_trip_df['starttime'], yearfirst=True)
citibike_trip_df['stoptime'] = pd.to_datetime(citibike_trip_df['stoptime'])
citibike_trip_df
# Out:
#                      starttime                stoptime  \
# 0      2018-09-01 00:00:05.269 2018-09-01 00:27:20.634
# 1      2018-09-01 00:00:11.281 2018-09-01 00:02:23.481
# 2      2018-09-01 00:00:20.649 2018-09-01 00:55:58.547
# 3      2018-09-01 00:00:21.746 2018-09-01 00:07:38.583
# 4      2018-09-01 00:00:27.315 2018-09-01 02:21:25.308
# ...                        ...                     ...
# 299995 2018-09-05 19:08:27.846 2018-09-05 19:15:51.494
# 299996 2018-09-05 19:08:28.370 2018-09-05 19:20:01.508
# 299997 2018-09-05 19:08:27.509 2018-09-05 19:13:40.506
# 299998 2018-09-05 19:08:29.230 2018-09-05 20:04:29.322
# 299999 2018-09-05 19:08:29.711 2018-09-05 19:12:14.762
#
#                      start station name  start station latitude  \
# 0          MacDougal St & Washington Sq               40.732264
# 1       Cadman Plaza West & Montague St               40.693830
# 2                       1 Ave & E 62 St               40.761227
# ...

# %%
citibike_trip_df['trip duration'] = citibike_trip_df['stoptime'] - citibike_trip_df['starttime']
citibike_trip_df['trip duration']
# Out:
# 0        0 days 00:27:15.365000
# 1        0 days 00:02:12.200000
# 2        0 days 00:55:37.898000
# 3        0 days 00:07:16.837000
# 4        0 days 02:20:57.993000
#                   ...
# 299995   0 days 00:07:23.648000
# 299996   0 days 00:11:33.138000
# 299997   0 days 00:05:12.997000
# 299998   0 days 00:56:00.092000
# 299999   0 days 00:03:45.051000
# Name: trip duration, Length: 300000, dtype: timedelta64[ns]

# %%
citibike_trip_df['trip duration'] = citibike_trip_df['trip duration'].dt.minute
citibike_trip_df['trip duration']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 citibike_trip_df['trip duration'] = citibike_trip_df['trip duration'].dt.minute
#       2 citibike_trip_df['trip duration']
#
# AttributeError: 'TimedeltaProperties' object has no attribute 'minute'

# %% [markdown]
# #### Задание 6.11 - Создайте «признак-мигалку» weekend, который равен 1, если поездка начиналась в выходной день (суббота или воскресенье), и 0 — в противном случае. Выясните, сколько поездок начиналось в выходные.

# %%
def isWeekend(day):
    if day in [5, 6]:
        return 1
    return 0

# %%
citibike_trip_df['weekend'] = citibike_trip_df['starttime'].dt.dayofweek.apply(isWeekend)
citibike_trip_df
# Out:
#                      starttime                stoptime  \
# 0      2018-09-01 00:00:05.269 2018-09-01 00:27:20.634
# 1      2018-09-01 00:00:11.281 2018-09-01 00:02:23.481
# 2      2018-09-01 00:00:20.649 2018-09-01 00:55:58.547
# 3      2018-09-01 00:00:21.746 2018-09-01 00:07:38.583
# 4      2018-09-01 00:00:27.315 2018-09-01 02:21:25.308
# ...                        ...                     ...
# 299995 2018-09-05 19:08:27.846 2018-09-05 19:15:51.494
# 299996 2018-09-05 19:08:28.370 2018-09-05 19:20:01.508
# 299997 2018-09-05 19:08:27.509 2018-09-05 19:13:40.506
# 299998 2018-09-05 19:08:29.230 2018-09-05 20:04:29.322
# 299999 2018-09-05 19:08:29.711 2018-09-05 19:12:14.762
#
#                      start station name  start station latitude  \
# 0          MacDougal St & Washington Sq               40.732264
# 1       Cadman Plaza West & Montague St               40.693830
# 2                       1 Ave & E 62 St               40.761227
# ...

# %%
citibike_trip_df[citibike_trip_df['weekend'] == 1].shape[0]
# Out:
# 115135

# %% [markdown]
# #### Задание 6.12 - Создайте признак времени суток поездки time_of_day. Время суток будем определять из часа начала поездки. Условимся, что:
# ##### поездка совершается ночью (night), если её час приходится на интервал от 0 (включительно) до 6 (включительно) часов;
# ##### поездка совершается утром (morning), если её час приходится на интервал от 6 (не включительно) до 12 (включительно) часов;
# ##### поездка совершается днём (day), если её час приходится на интервал от 12 (не включительно) до 18 (включительно) часов;
# ##### поездка совершается вечером (evening), если её час приходится на интервал от 18 (не включительно) до 23 часов (включительно).
# ##### Во сколько раз количество поездок, совершённых днём, больше, чем количество поездок, совёршенных ночью, за представленный в данных период времени? Ответ округлите до целых.

# %%
def getTimeOfDay(hour):
    if hour in range(7):
        return 'night'
    if hour in range(7, 13):
        return 'morning'
    if hour in range(13, 19):
        return 'day'
    return 'evening'

# %%
citibike_trip_df['time_of_day'] = citibike_trip_df['starttime'].dt.hour.apply(getTimeOfDay)
citibike_trip_df
# Out:
#                      starttime                stoptime  \
# 0      2018-09-01 00:00:05.269 2018-09-01 00:27:20.634
# 1      2018-09-01 00:00:11.281 2018-09-01 00:02:23.481
# 2      2018-09-01 00:00:20.649 2018-09-01 00:55:58.547
# 3      2018-09-01 00:00:21.746 2018-09-01 00:07:38.583
# 4      2018-09-01 00:00:27.315 2018-09-01 02:21:25.308
# ...                        ...                     ...
# 299995 2018-09-05 19:08:27.846 2018-09-05 19:15:51.494
# 299996 2018-09-05 19:08:28.370 2018-09-05 19:20:01.508
# 299997 2018-09-05 19:08:27.509 2018-09-05 19:13:40.506
# 299998 2018-09-05 19:08:29.230 2018-09-05 20:04:29.322
# 299999 2018-09-05 19:08:29.711 2018-09-05 19:12:14.762
#
#                      start station name  start station latitude  \
# 0          MacDougal St & Washington Sq               40.732264
# 1       Cadman Plaza West & Montague St               40.693830
# 2                       1 Ave & E 62 St               40.761227
# ...

# %%
citibike_trip_df['time_of_day'] = citibike_trip_df['time_of_day'].astype('category')

# %%
day_rides = citibike_trip_df[citibike_trip_df['time_of_day'] == 'day'].shape[0]
night_rides = citibike_trip_df[citibike_trip_df['time_of_day'] == 'night'].shape[0]
display(round(day_rides/night_rides))
# Out:
# 9
